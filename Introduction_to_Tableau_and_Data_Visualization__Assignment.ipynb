# %% [markdown]
# #Introduction to Tableau and Data Visualization| Assignment

# %% [markdown]
# #questions
#
#
#
# Question 1 : What is Tableau? Explain its importance in Business Intelligence and how it helps in data-driven decision-making.
#
# Question 2 : Explain the role of the following Tableau components: a) Data Pane b) Worksheet c) Dashboard d) Story
#
# Question 3 : What is the difference between Dimensions and Measures in Tableau? Provide examples of each.
#
# Question 4 : Define and explain the purpose of Filters, Parameters, and Sets in Tableau.
#
# Question 5 : Create a bar chart showing Gross Sales by Country. ● 🔗 Dataset Link:Global_sales_dataset ● Sort the countries in descending order of sales ● Highlight or annotate the bar that represents the maximum and minimum Gross Sales. ● Add data labels and format the chart for presentation.
#
# Question 6 : Using Tableau, create a dual-axis chart that displays: ● 🔗 Dataset Link:Global_sales_dataset ● Monthly Sales as bars ● Monthly Profit as a line ● Filter the data to include only records from the year 2014 ● Ensure both axes are synchronized and properly labeled ● Add an appropriate chart title, and format the chart for clear visual presentation ● Paste a screenshot of the final chart in your submission
#
# Question 7 : Create a filled map showing total Units Sold by Country. ● 🔗 Dataset Link:Global_sales_dataset ● Add a parameter to allow users to switch between Units Sold and Profit. ● Use the Discount Band as a filter in your visualization.
#
# Question 8 : Create a dashboard that includes: ● 🔗 Dataset Link:Global_sales_dataset ● KPI tiles for Total Sales, Total Profit, and Total Units Sold ● A line chart for Profit trend over time ● Filters for Product and Country Ensure your dashboard is interactive and visually appealing.
#
# Question 9 : Your goal is to identify products that generate low profit despite high sales volume. ● 🔗 Dataset Link:Global_sales_dataset ● Use scatter plot or highlight table to identify such products. ● Add filters for Country and Segment. ● Write two business insights based on your chart.
#
# Question 10 : [Scenario-Based – Customer Behavior & Retention Strategy] Dataset to Use: online_retail_II Dataset Name: Online Retail II Dataset Source: UCI Machine Learning Repository – Online Retail II Dataset .
#
# Business Scenario: You are a Data Analyst at an e-commerce company that sells home decor and gifts across multiple countries. The leadership team is concerned about customer churn and revenue loss due to inconsistent customer behavior. They’ve asked you to investigate patterns in customer orders, returns, and geographic sales performance from the Online Retail II dataset. Your Task in Tableau: 1. Use Tableau to answer these questions: ○ Which countries have the highest number of repeat customers? ○ What is the return rate by product and Find top 10 countries? ○ What time of year do customers tend to buy the most (Seasonality) ? ○ Are there certain customers with high order value but also high return rates? 2. Create visualizations: ○ A map showing Revenue by Country ○ A line chart of Monthly Sales Trend ○ A bar chart showing Top 10 customers by Total Revenue ○ A table/heatmap showing Top returned products by country 3. Build a dashboard for business insights: ○ Allow filters for Country, Product, and Customer ID ○ Use KPIs for: ■ Total Revenue ■ Total Returns ■ Repeat Customer Count 4. Write a short business insight (2–3 sentences): Based on your Tableau dashboard, what recommendations would you make to help reduce churn and increase customer loyalty?

# %% [markdown]
# #answers
#
# ans1. What is Tableau & its importance in BI
#
# Tableau is a data visualization and Business Intelligence tool used to analyze data visually. It helps businesses make data-driven decisions by identifying trends, patterns, and insights quickly.
#
# ans2. Tableau components
# a) Data Pane – Shows fields (dimensions & measures) from the data source
# b) Worksheet – Area to create individual visualizations
# c) Dashboard – Combines multiple worksheets into one view
# d) Story – Sequence of views to explain insights step-by-step
#
# ans3. Dimensions vs Measures
#
# Dimensions: Categorical fields (e.g., Country, Product, Date)
#
# Measures: Numerical fields (e.g., Sales, Profit, Units Sold)
#
#
# ans4. Filters, Parameters, Sets
#
# Filters: Limit data shown (e.g., Year = 2014)
#
# Parameters: User-controlled input (e.g., Units Sold vs Profit)
#
# Sets: Custom group of data based on conditions (e.g., Top 10 products)
#
#
# ans5. Bar chart – Gross Sales by Country
#
# Country → Rows, Gross Sales → Columns
#
# Sort descending by Gross Sales
#
# Show data labels
#
# Highlight max & min bars using color or annotation
#
# Format axes, title, and labels
#
#
# ans6. Dual-axis chart (2014)
#
# Date (Month) → Columns
#
# Sales → Bars, Profit → Line
#
# Filter Year = 2014
#
# Dual-axis → Synchronize axes
#
# Add title and labels
#
#
# ans7. Filled map – Units Sold / Profit
#
# Country → Map
#
# Create parameter (Units Sold / Profit)
#
# Use calculated field with parameter
#
# Apply Discount Band as filter
#
#
# ans8. Dashboard creation
#
# KPI tiles: Total Sales, Profit, Units Sold
#
# Line chart: Profit over time
#
# Add Product & Country filters
#
# Ensure interactivity and clean layout
#
#
# ans9. Low profit, high sales products
#
# Scatter plot: Sales vs Profit by Product
#
# Identify high sales & low profit items
#
# Filters: Country, Segment
# Insights:
#
# Some products sell well but have low margins.
#
# Discounts or high costs reduce profitability.
#
#
# ans10. Scenario-based (Online Retail II)
#
# Key findings (using Tableau):
#
# UK and Germany have highest repeat customers
#
# Returns are highest for certain gift items
#
# Peak sales occur in Nov–Dec (seasonality)
#
# Some high-value customers also have high return rates
#
# Dashboard visuals:
#
# Map: Revenue by Country
#
# Line chart: Monthly Sales
#
# Bar chart: Top 10 customers
#
# Heatmap: Returned products by country
#
# Business insight (2–3 lines):
# Focus on retaining repeat customers in top countries with loyalty offers. Reduce returns by improving product quality and targeting high-return customers with better policies and communication.
